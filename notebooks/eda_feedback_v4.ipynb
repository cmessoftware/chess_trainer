# %% [markdown]
# ## 1- Carga librerias necesarias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## 2- Cargar dataset desde sqlite

# %%
# Conectar a la base y leer tabla 'features'
import sqlite3
import pandas as pd


conn = sqlite3.connect("/app/src/data/chess_trainer.db")
df = pd.read_sql_query("SELECT * FROM features", conn)
conn.close()

print(f"✔️ Dataset cargado: {df.shape[0]} registros y {df.shape[1]} columnas")
df.head()
# Out:
# ✔️ Dataset cargado: 2748 registros y 21 columnas
#                             game_id  move_number  \
# 0  8681a047cfccf627bd4f4a77d206a760            1
# 1  8681a047cfccf627bd4f4a77d206a760            1
# 2  8681a047cfccf627bd4f4a77d206a760            2
# 3  8681a047cfccf627bd4f4a77d206a760            2
# 4  8681a047cfccf627bd4f4a77d206a760            3
#
#                                                  fen move_san move_uci  \
# 0  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...       e4     e2e4
# 1  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...       e6     e7e6
# 2  rnbqkbnr/pppp1ppp/4p3/8/4P3/8/PPPP1PPP/RNBQKBN...       d4     d2d4
# 3  rnbqkbnr/pppp1ppp/4p3/8/3PP3/8/PPP2PPP/RNBQKBN...       d5     d7d5
# 4  rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/8/PPP2PPP/RNBQKB...       e5     e4e5
#
#    material_balance  material_total  num_pieces  branching_factor  \
# 0               0.0            79.0          14                40
# ...

# %% [markdown]
# Generar documento PDF.

# %%
from fpdf import FPDF

class PDF(FPDF):
    def header(self):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, 'Informe EDA Chess Trainer', 0, 1, 'C')

    def chapter_title(self, title):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'L')
        self.ln(4)

    def chapter_body(self, body):
        self.set_font('Arial', '', 12)
        for line in body:
            self.multi_cell(0, 10, line)
        self.ln()

    def print_chapter(self, title, body):
        self.add_page()
        self.chapter_title(title)
        self.chapter_body(body)

pdf = PDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.print_chapter("Resumen del análisis táctico", summary_lines)
pdf.output("eda_tactical_summary.pdf")
